# %% [markdown]
# # Upload to Kaggle
#
# Run this after `02_score_and_export.ipynb` has written `output/movie_vad_scores.csv`.
#
# ```bash
# # First time:
# kaggle datasets create -p output
#
# # Subsequent updates:
# kaggle datasets version -p output -m "your message"
# ```

# %%
# Run from terminal (requires KAGGLE_API_TOKEN in .env)
# !kaggle datasets version -p output -m "Updated scores"
print('Run the kaggle CLI command above from your terminal.')
